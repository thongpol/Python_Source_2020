# %%
while True:
    i = input("ต้องการป้อนคะแนนให้กด Y ออกจากโปรแกรมให้กด N : ")
    print ("-----------------------------------------------")
    if i == "N":
        break
    elif i == "Y":
        n = int(input("นักเรียนคนที่ = "))
        j = 1
        lst = []
        while j <= 3:
            score = float(input("กรอกคะแนนครั้งที่ %d = " %j))
            lst.append(score)
            j += 1
        print ("นักเรียนคนที่ %d ได้คะแนน = " %n, lst, "คะแนนรวม =", sum(lst))
        print("----------------------------------------------------------")
print ("สิ้นสุดการทำงานของโปรแกรม")
# Out:
# ต้องการป้อนคะแนนให้กด Y ออกจากโปรแกรมให้กด N : Y
# -----------------------------------------------
# นักเรียนคนที่ = 1
# กรอกคะแนนครั้งที่ 1 = 15
# กรอกคะแนนครั้งที่ 2 = 25
# กรอกคะแนนครั้งที่ 3 = 32
# นักเรียนคนที่ 1 ได้คะแนน =  [15.0, 25.0, 32.0] คะแนนรวม = 72.0
# ----------------------------------------------------------
# ต้องการป้อนคะแนนให้กด Y ออกจากโปรแกรมให้กด N : Y
# -----------------------------------------------
# นักเรียนคนที่ = 2
# กรอกคะแนนครั้งที่ 1 = 34
# กรอกคะแนนครั้งที่ 2 = 12
# กรอกคะแนนครั้งที่ 3 = 30
# นักเรียนคนที่ 2 ได้คะแนน =  [34.0, 12.0, 30.0] คะแนนรวม = 76.0
# ----------------------------------------------------------
# ต้องการป้อนคะแนนให้กด Y ออกจากโปรแกรมให้กด N : N
# -----------------------------------------------
# สิ้นสุดการทำงานของโปรแกรม
