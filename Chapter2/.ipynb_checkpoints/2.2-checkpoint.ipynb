# %%
print ("Hello Python", 'Hello Python programming')
print (50)
print ("Hello" + "Python")
print ("Hello" + ' ' + "Python")
print ()
print (5*10/2)
# Out:
# Hello Python Hello Python programming
# 50
# HelloPython
# Hello Python
#
# 25.0
