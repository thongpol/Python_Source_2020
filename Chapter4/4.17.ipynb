# %%
print("สมใจ เรียนวิชา {} ได้คะแนน\n\
ทดสอบครั้งที่ 1 = {}\n\
ทดสอบครั้งที่ 2 = {:.2f}\n\
ทดสอบครั้งที่ 3 = {:.2f}\n\
ได้เกรด = {}" .format("Database System", 30, 25.50, 25.50, "A"))
# Out:
# สมใจ เรียนวิชา Database System ได้คะแนน
# ทดสอบครั้งที่ 1 = 30
# ทดสอบครั้งที่ 2 = 25.50
# ทดสอบครั้งที่ 3 = 25.50
# ได้เกรด = A
